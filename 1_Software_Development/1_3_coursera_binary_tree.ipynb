# %%
class TreeNode:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

class BinaryTree:
    def __init__(self):
        self.root = None

    def insert(self, key):
        if self.root is None:
            self.root = TreeNode(key)
        else:
            self._insert(self.root, key)

    def _insert(self, node, key):
        if key < node.val:
            if node.left is None:
                node.left = TreeNode(key)
            else:
                self._insert(node.left, key)
        else:
            if node.right is None:
                node.right = TreeNode(key)
            else:
                self._insert(node.right, key)

    def inorder(self, node):
        if node:
            self.inorder(node.left)
            print(node.val, end=' ')
            self.inorder(node.right)

# Example usage
bt = BinaryTree()
bt.insert(8)
bt.insert(3)
bt.insert(10)
bt.insert(1)
bt.insert(6)
bt.insert(4)
bt.insert(7)

print("Inorder traversal of the binary tree:")
bt.inorder(bt.root)
# Out:
# Inorder traversal of the binary tree:
# 1 3 4 6 7 8 10

# %%
# As an Expert Software Engineer and a Site Reliability Engineer that puts code into production in large scale systems Can you analyze this implementataion of the Binary Tree above and update code to make it production ready. And is it missing any functionality that you would like to add to it? If so, please add it.

class TreeNode:
    def __init__(self, key: int):
        self.left: TreeNode | None = None
        self.right: TreeNode | None = None
        self.val: int = key

class BinaryTree:
    def __init__(self):
        self.root: TreeNode | None = None

    def insert(self, key: int) -> None:
        """Insert a new node with the given key."""
        if self.root is None:
            self.root = TreeNode(key)
        else:
            self._insert(self.root, key)

    def _insert(self, node: TreeNode, key: int) -> None:
        if key < node.val:
            if node.left is None:
                node.left = TreeNode(key)
            else:
                self._insert(node.left, key)
        else:
            if node.right is None:
                node.right = TreeNode(key)
            else:
                self._insert(node.right, key)

    def inorder(self, node: TreeNode | None) -> None:
        """Inorder traversal of the binary tree."""
        if node:
            self.inorder(node.left)
            print(node.val, end=' ')
            self.inorder(node.right)

    def preorder(self, node: TreeNode | None) -> None:
        """Preorder traversal of the binary tree."""
        if node:
            print(node.val, end=' ')
            self.preorder(node.left)
            self.preorder(node.right)

    def postorder(self, node: TreeNode | None) -> None:
        """Postorder traversal of the binary tree."""
        if node:
            self.postorder(node.left)
            self.postorder(node.right)
            print(node.val, end=' ')

    def search(self, key: int) -> TreeNode | None:
        """Search for a node with the given key."""
        return self._search(self.root, key)

    def _search(self, node: TreeNode | None, key: int) -> TreeNode | None:
        if node is None or node.val == key:
            return node
        if key < node.val:
            return self._search(node.left, key)
        return self._search(node.right, key)

    def delete(self, key: int) -> None:
        """Delete a node with the given key."""
        self.root = self._delete(self.root, key)

    def _delete(self, node: TreeNode | None, key: int) -> TreeNode | None:
        if node is None:
            return node
        if key < node.val:
            node.left = self._delete(node.left, key)
        elif key > node.val:
            node.right = self._delete(node.right, key)
        else:
            if node.left is None:
                return node.right
            elif node.right is None:
                return node.left
            temp = self._min_value_node(node.right)
            node.val = temp.val
            node.right = self._delete(node.right, temp.val)
        return node

    def _min_value_node(self, node: TreeNode) -> TreeNode:
        current = node
        while current.left is not None:
            current = current.left
        return current

# Example usage
bt = BinaryTree()
bt.insert(8)
bt.insert(3)
bt.insert(10)
bt.insert(1)
bt.insert(6)
bt.insert(4)
bt.insert(7)

print("Inorder traversal of the binary tree:")
bt.inorder(bt.root)
print("\nPreorder traversal of the binary tree:")
bt.preorder(bt.root)
print("\nPostorder traversal of the binary tree:")
bt.postorder(bt.root)
print("\nSearch for node with value 6:")
found_node = bt.search(6)
print(found_node.val if found_node else "Not found")
print("Delete node with value 10:")
bt.delete(10)
print("Inorder traversal after deletion:")
bt.inorder(bt.root)
# Out:
# Inorder traversal of the binary tree:
# 1 3 4 6 7 8 10
# Preorder traversal of the binary tree:
# 8 3 1 6 4 7 10
# Postorder traversal of the binary tree:
# 1 4 7 6 3 10 8
# Search for node with value 6:
# 6
# Delete node with value 10:
# Inorder traversal after deletion:
# 1 3 4 6 7 8

# %%
# What is preorder and postorder traversal of a Binary Search Tree?

# %%
# Prompt 1 - As my Python mentor can you write an implementation of “Binary Search Tree” in Python which uses easy to understand code and the functions and documentation needed to do the following with the Binary Search Tree
# Make sure to check the Performance of the code and Security of the code and make sure it is production ready
# 1. If the value you want to add is bigger than the current one, you insert it as the right child; otherwise, you insert it as the left child.
# 2. Function to print the full Tree
# 3. Function to search an element in the Tree
# 4. Delete a specified element
# 5. Print statistics like number of active items in it and the total memory it is occupying
# Feel free to add other necessary functions which you think we can need

# %%
import sys

class TreeNode:
    def __init__(self, key: int):
        self.left: TreeNode | None = None
        self.right: TreeNode | None = None
        self.val: int = key

class BinarySearchTree:
    def __init__(self):
        self.root: TreeNode | None = None
        self.size: int = 0

    def insert(self, key: int) -> None:
        """Insert a new node with the given key."""
        if self.root is None:
            self.root = TreeNode(key)
        else:
            self._insert(self.root, key)
        self.size += 1

    def _insert(self, node: TreeNode, key: int) -> None:
        if key < node.val:
            if node.left is None:
                node.left = TreeNode(key)
            else:
                self._insert(node.left, key)
        else:
            if node.right is None:
                node.right = TreeNode(key)
            else:
                self._insert(node.right, key)

    def search(self, key: int) -> TreeNode | None:
        """Search for a node with the given key."""
        return self._search(self.root, key)

    def _search(self, node: TreeNode | None, key: int) -> TreeNode | None:
        if node is None or node.val == key:
            return node
        if key < node.val:
            return self._search(node.left, key)
        return self._search(node.right, key)

    def delete(self, key: int) -> None:
        """Delete a node with the given key."""
        self.root = self._delete(self.root, key)

    def _delete(self, node: TreeNode | None, key: int) -> TreeNode | None:
        if node is None:
            return node
        if key < node.val:
            node.left = self._delete(node.left, key)
        elif key > node.val:
            node.right = self._delete(node.right, key)
        else:
            if node.left is None:
                return node.right
            elif node.right is None:
                return node.left
            temp = self._min_value_node(node.right)
            node.val = temp.val
            node.right = self._delete(node.right, temp.val)
        return node

    def _min_value_node(self, node: TreeNode) -> TreeNode:
        current = node
        while current.left is not None:
            current = current.left
        return current
    



    def print_tree(self) -> None:
        """Print the full tree."""
        self._print_tree(self.root)
        print()

    def _print_tree(self, node: TreeNode | None) -> None:
        if node:
            self._print_tree(node.left)
            print(node.val, end=' ')
            self._print_tree(node.right)

    def print_statistics(self) -> None:
        """Print statistics like number of active items and total memory occupied."""
        print(f"Number of active items: {self.size}")
        print(f"Total memory occupied: {sys.getsizeof(self)} bytes") 

# Example usage
bst = BinarySearchTree()
bst.insert(8)
bst.insert(3)
bst.insert(10)
bst.insert(1)
bst.insert(6)
bst.insert(4)
bst.insert(7)

print("Full tree:")
bst.print_tree()
print("Search for node with value 6:")
found_node = bst.search(6)
print(found_node.val if found_node else "Not found")
print("Delete node with value 10:")
bst.delete(10)
print("Full tree after deletion:")
bst.print_tree()
bst.print_statistics()
# Out:
# Full tree:
# 1 3 4 6 7 8 10
# Search for node with value 6:
# 6
# Delete node with value 10:
# Full tree after deletion:
# 1 3 4 6 7 8
# Number of active items: 7
# Total memory occupied: 48 bytes
